# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulrahman-Mahmoud-12/ENDO-X/blob/osama/ENDOX_Exp10_YOLOv11s_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U ultralytics -q

import os, zipfile

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d debeshjha1/kvasirseg

with zipfile.ZipFile('kvasirseg.zip', 'r') as zip_ref:
  zip_ref.extractall('kvasir')

print(os.listdir('kvasir/Kvasir-SEG/Kvasir-SEG'))
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 52.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 5.2 MB/s eta 0:00:00
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2)
# Dataset URL: https://www.kaggle.com/datasets/debeshjha1/kvasirseg
# License(s): copyright-authors
# Downloading kvasirseg.zip to /content
# 100% 144M/144M [00:04<00:00, 33.9MB/s]
#
# ['annotated_images', 'masks', 'images', 'bbox', '1911.07069.pdf']

# %%
import os, cv2, csv, shutil, random, yaml, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from ultralytics import YOLO
import torch

print('GPU:', torch.cuda.is_available())
if torch.cuda.is_available():
  print(torch.cuda.get_device_name(0))
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart#ultralytics-settings.
# GPU: True
# Tesla T4

# %%
IMAGE_DIR = 'kvasir/Kvasir-SEG/Kvasir-SEG/images'
CSV_DIR   = 'kvasir/Kvasir-SEG/Kvasir-SEG/bbox'

all_keys = [f.replace('.jpg', '') for f in os.listdir(IMAGE_DIR) if f.endswith('.jpg')]

print('Total images:', len(all_keys))

with open(os.path.join(CSV_DIR, all_keys[0] + '.csv'), 'r') as f:
  print(f.read())
# Out:
# Total images: 1000
# class_name,xmin,ymin,xmax,ymax
# polyp,372,226,607,389

# %%
sample_keys = random.sample(all_keys, 6)

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
fig.suptitle('Kvasir-SEG — YOLOv11s', fontsize=14, fontweight='bold')
axes = axes.flatten()

for i, key in enumerate(sample_keys):
  img = cv2.imread(os.path.join(IMAGE_DIR, key + '.jpg'))
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

  with open(os.path.join(CSV_DIR, key + '.csv'), 'r') as f:
    row = next(csv.DictReader(f))

  bx = float(row['xmin'])
  by = float(row['ymin'])
  bw = float(row['xmax']) - bx
  bh = float(row['ymax']) - by

  axes[i].imshow(img)
  axes[i].add_patch(patches.Rectangle((bx, by), bw, bh, linewidth=3, edgecolor='lime', facecolor='none'))
  axes[i].set_title(f'{img.shape[1]}x{img.shape[0]}')
  axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
def read_bbox_csv(csv_path, img_w, img_h):
  with open(csv_path, 'r') as f:
    row = next(csv.DictReader(f))
  x1 = float(row['xmin']);  y1 = float(row['ymin'])
  x2 = float(row['xmax']);  y2 = float(row['ymax'])
  bw = x2 - x1;             bh = y2 - y1
  cx = max(0., min(1., (x1 + bw / 2) / img_w))
  cy = max(0., min(1., (y1 + bh / 2) / img_h))
  nw = max(0., min(1., bw / img_w))
  nh = max(0., min(1., bh / img_h))
  return f'0 {cx:.6f} {cy:.6f} {nw:.6f} {nh:.6f}'


BASE = 'dataset'
for split in ['train', 'val', 'test']:
  os.makedirs(f'{BASE}/images/{split}', exist_ok=True)
  os.makedirs(f'{BASE}/labels/{split}', exist_ok=True)

train_keys, temp_keys = train_test_split(all_keys, test_size=0.30, random_state=42)
val_keys,   test_keys = train_test_split(temp_keys, test_size=0.50, random_state=42)

print(f'Train:{len(train_keys)} | Val:{len(val_keys)} | Test:{len(test_keys)}')

def build_split(keys, split_name):
  for key in keys:
    img_path = os.path.join(IMAGE_DIR, key + '.jpg')
    csv_path = os.path.join(CSV_DIR,   key + '.csv')
    img      = cv2.imread(img_path)
    h, w     = img.shape[:2]
    shutil.copy(img_path, f'{BASE}/images/{split_name}/{key}.jpg')
    with open(f'{BASE}/labels/{split_name}/{key}.txt', 'w') as f:
      f.write(read_bbox_csv(csv_path, w, h) + '\n')

build_split(train_keys, 'train')
build_split(val_keys,   'val')
build_split(test_keys,  'test')

print('Done')
print('images/train:', len(os.listdir(f'{BASE}/images/train')))
print('labels/train:', len(os.listdir(f'{BASE}/labels/train')))
# Out:
# Train:700 | Val:150 | Test:150
# Done
# images/train: 700
# labels/train: 700

# %%
dataset_yaml = {
    'path' : '/content/dataset',
    'train': 'images/train',
    'val'  : 'images/val',
    'test' : 'images/test',
    'nc'   : 1,
    'names': ['polyp']
}

yaml_path = 'kvasir_detection.yaml'
with open(yaml_path, 'w') as f:
  yaml.dump(dataset_yaml, f, default_flow_style=False)

with open(yaml_path, 'r') as f:
  print(f.read())
# Out:
# names:
# - polyp
# nc: 1
# path: /content/dataset
# test: images/test
# train: images/train
# val: images/val

# %%
MODEL_SIZE    = 'yolo11s.pt'
IMG_SIZE      = 640
EPOCHS        = 100
BATCH_SIZE    = 16
LR0           = 0.005
LRF           = 0.0005
WARMUP_EPOCHS = 5
PATIENCE      = 30
CLOSE_MOSAIC  = 15
CONF_THRESH   = 0.15
IOU_THRESH    = 0.35

print(f'Model       : yolo11s.pt')
print(f'Epochs      : {EPOCHS}')
print(f'Batch       : {BATCH_SIZE}')
print(f'LR          : {LR0} → {LRF}')
print(f'Conf thresh : {CONF_THRESH}')
print(f'IoU thresh  : {IOU_THRESH}')
# Out:
# Model       : yolo11s.pt
# Epochs      : 100
# Batch       : 16
# LR          : 0.005 → 0.0005
# Conf thresh : 0.15
# IoU thresh  : 0.35

# %%
model = YOLO(MODEL_SIZE)
print(f'Params: {sum(p.numel() for p in model.model.parameters()):,}')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 139.4MB/s 0.1s
# Params: 9,458,752

# %%
results = model.train(
    data          = yaml_path,
    epochs        = EPOCHS,
    imgsz         = IMG_SIZE,
    batch         = BATCH_SIZE,
    lr0           = LR0,
    lrf           = LRF,
    warmup_epochs = WARMUP_EPOCHS,
    patience      = PATIENCE,
    close_mosaic  = CLOSE_MOSAIC,
    optimizer     = 'Adam',
    cos_lr        = True,
    augment       = True,
    mosaic        = 1.0,
    mixup         = 0.15,
    degrees       = 15.0,
    scale         = 0.6,
    shear         = 2.0,
    fliplr        = 0.5,
    flipud        = 0.3,
    hsv_h         = 0.02,
    hsv_s         = 0.8,
    hsv_v         = 0.5,
    save          = True,
    project       = 'ENDOX_runs',
    name          = 'exp10_yolo11s',
    verbose       = True
)

print('Done')
# Out:
# Ultralytics 8.4.129 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=15, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=kvasir_detection.yaml, degrees=15.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.3, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.02, hsv_s=0.8, hsv_v=0.5, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.005, lrf=0.0005, mask_ratio=4, max_det=300, mixup=0.15, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp10_yolo11s, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=ENDOX_runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/ENDOX_runs/exp10_yolo11s, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.6, seed=0, shear=2.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=5, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 40.3MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    819795  ultralytics.nn.modules.head.Detect           [1, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,428,179 parameters, 9,428,163 gradients, 21.7 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: downloading yolo26n.pt for AMP checks (one-time, not used for training)...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'weights/yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 128.0MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1300.6±473.1 MB/s, size: 46.7 KB)
# train: Scanning /content/dataset/labels/train... 700 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 700/700 2.2Kit/s 0.3s
# train: New cache created: /content/dataset/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 602.2±307.5 MB/s, size: 59.5 KB)
# val: Scanning /content/dataset/labels/val... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 963.2it/s 0.2s
# val: New cache created: /content/dataset/labels/val.cache
# optimizer: Adam(lr=0.005, momentum=0.937) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /content/runs/detect/ENDOX_runs/exp10_yolo11s/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/ENDOX_runs/exp10_yolo11s
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      4.07G      1.875      3.387      2.075         24        640: 100% ━━━━━━━━━━━━ 44/44 1.3it/s 34.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.9s/it 14.4s
#                    all        150        150   0.000224     0.0667   1.47e-05   3.67e-06
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      5.46G      1.813      2.234      2.068         32        640: 100% ━━━━━━━━━━━━ 44/44 3.2it/s 13.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.4it/s 2.1s
#                    all        150        150          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      5.46G      1.839      2.184      2.046         31        640: 100% ━━━━━━━━━━━━ 44/44 3.2it/s 13.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        150        150    0.00705        0.4    0.00433     0.0012
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      5.46G      1.796      2.161      2.035         39        640: 100% ━━━━━━━━━━━━ 44/44 3.3it/s 13.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s
#                    all        150        150   0.000844      0.253   0.000242   5.69e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      5.46G      1.728      2.204      1.992         21        640: 100% ━━━━━━━━━━━━ 44/44 3.2it/s 13.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.5it/s 1.4s
#                    all        150        150   0.000467       0.14   6.32e-05   1.63e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      5.46G      1.726      2.143      1.996         31        640: 100% ━━━━━━━━━━━━ 44/44 3.2it/s 13.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.5it/s 1.4s
#                    all        150        150      0.317      0.293      0.189     0.0628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      5.46G      1.696      2.088      1.968         32        640: 100% ━━━━━━━━━━━━ 44/44 3.3it/s 13.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.7it/s 1.3s
#                    all        150        150     0.0301      0.753     0.0277     0.0133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      5.46G      1.641      1.987      1.916         33        640: 100% ━━━━━━━━━━━━ 44/44 3.2it/s 13.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.5it/s 2.0s
#                    all        150        150       0.39      0.549      0.376      0.115
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      5.46G      1.607      2.002      1.902         33        640: 100% ━━━━━━━━━━━━ 44/44 3.3it/s 13.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.1it/s 1.6s
#                    all        150        150      0.491      0.533      0.477      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      5.46G      1.604      1.985      1.884         30        640: 100% ━━━━━━━━━━━━ 44/44 3.2it/s 13.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.7it/s 1.3s
#                    all        150        150       0.59      0.473      0.543      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      5.46G      1.638      1.878      1.904         39        640: 100% ━━━━━━━━━━━━ 44/44 3.3it/s 13.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.9it/s 1.3s
#                    all        150        150      0.509       0.38      0.399      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      5.46G      1.599      1.882      1.875         25        640: 100% ━━━━━━━━━━━━ 44/44 3.3it/s 13.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.6it/s 1.4s
#                    all        150        150      0.519      0.647      0.568      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      5.46G      1.607      1.889      1.845         32        640: 100% ━━━━━━━━━━━━ 44/44 3.2it/s 13.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.5it/s 1.4s
#                    all        150        150      0.457        0.6      0.509      0.195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      5.46G      1.548      1.886      1.804         31        640: 100% ━━━━━━━━━━━━ 44/44 3.2it/s 13.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.1it/s 1.6s
#                    all        150        150      0.676      0.593      0.643      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      5.46G      1.558      1.876      1.831         34        640: 100% ━━━━━━━━━━━━ 44/44 3.3it/s 13.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.4it/s 2
640: 100% ━━━━━━━━━━━━ 44/44 3.2it/s 13.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.9it/s 1.3s
#                    all        150        150        0.8      0.852      0.885      0.631
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      5.46G     0.9133     0.9722      1.355         12        640: 100% ━━━━━━━━━━━━ 44/44 2.9it/s 15.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        150        150      0.786       0.86      0.883      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      5.46G     0.9301     0.8586       1.37         12        640: 100% ━━━━━━━━━━━━ 44/44 3.4it/s 13.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.0it/s 1.3s
#                    all        150        150      0.802      0.787      0.875       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      5.46G     0.9204     0.8519      1.371         12        640: 100% ━━━━━━━━━━━━ 44/44 3.5it/s 12.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.8it/s 1.3s
#                    all        150        150      0.851      0.802      0.893      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      5.46G     0.8884     0.7758      1.336         12        640: 100% ━━━━━━━━━━━━ 44/44 3.5it/s 12.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.6it/s 1.4s
#                    all        150        150      0.884      0.813      0.898       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      5.46G     0.8745     0.7606      1.319         12        640: 100% ━━━━━━━━━━━━ 44/44 3.4it/s 12.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.9it/s 1.3s
#                    all        150        150      0.837      0.825        0.9      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      5.46G     0.8902     0.7404      1.333         12        640: 100% ━━━━━━━━━━━━ 44/44 3.5it/s 12.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.6it/s 1.4s
#                    all        150        150      0.858      0.846      0.903      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      5.46G     0.8673      0.736       1.33         12        640: 100% ━━━━━━━━━━━━ 44/44 3.5it/s 12.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.0it/s 1.3s
#                    all        150        150      0.865      0.809      0.901      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      5.46G     0.8959     0.7345      1.359         12        640: 100% ━━━━━━━━━━━━ 44/44 3.5it/s 12.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.8it/s 1.3s
#                    all        150        150      0.895      0.799      0.893      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      5.46G     0.8925     0.7365      1.338         12        640: 100% ━━━━━━━━━━━━ 44/44 3.4it/s 12.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.0it/s 1.3s
#                    all        150        150      0.877       0.78      0.881      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      5.46G     0.8736     0.7406      1.342         12        640: 100% ━━━━━━━━━━━━ 44/44 3.4it/s 12.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.1it/s 1.2s
#                    all        150        150      0.849      0.807      0.885      0.665
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      5.46G      0.878      0.729      1.331         12        640: 100% ━━━━━━━━━━━━ 44/44 3.5it/s 12.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.9it/s 1.3s
#                    all        150        150      0.867      0.787      0.883      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      5.46G     0.8842     0.7303      1.327         12        640: 100% ━━━━━━━━━━━━ 44/44 3.4it/s 12.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.8it/s 1.3s
#                    all        150        150      0.844      0.813      0.887      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      5.46G      0.864     0.7273      1.321         12        640: 100% ━━━━━━━━━━━━ 44/44 3.6it/s 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.1it/s 1.6s
#                    all        150        150      0.833      0.827       0.89       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      5.46G     0.8599     0.7009       1.31         12        640: 100% ━━━━━━━━━━━━ 44/44 3.6it/s 12.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.6it/s 1.9s
#                    all        150        150      0.857      0.802      0.888      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      5.46G      0.876     0.7413      1.326         12        640: 100% ━━━━━━━━━━━━ 44/44 3.6it/s 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.9it/s 1.7s
#                    all        150        150      0.858      0.804      0.889      0.668
#
# 100 epochs completed in 0.445 hours.
# Optimizer stripped from /content/runs/detect/ENDOX_runs/exp10_yolo11s/weights/last.pt, 19.2MB
# Optimizer stripped from /content/runs/detect/ENDOX_runs/exp10_yolo11s/weights/best.pt, 19.2MB
#
# Validating /content/runs/detect/ENDOX_runs/exp10_yolo11s/weights/best.pt...
# Ultralytics 8.4.129 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,413,187 parameters, 0 gradients, 21.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.6s/it 23.2s
#                    all        150        150      0.852      0.833      0.915      0.673
# Speed: 0.3ms preprocess, 144.6ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to /content/runs/detect/ENDOX_runs/exp10_yolo11s
# Done

# %%
df = pd.read_csv('/content/runs/detect/ENDOX_runs/exp10_yolo11s/results.csv')
df.columns = df.columns.str.strip()
epochs = df['epoch']

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('YOLOv11s — Training History', fontsize=14, fontweight='bold')

axes[0,0].plot(epochs, df['train/box_loss'], label='Train', color='blue')
axes[0,0].plot(epochs, df['val/box_loss'],   label='Val',   color='orange')
axes[0,0].set_title('Box Loss');  axes[0,0].legend(); axes[0,0].grid(True)

axes[0,1].plot(epochs, df['train/cls_loss'], label='Train', color='blue')
axes[0,1].plot(epochs, df['val/cls_loss'],   label='Val',   color='orange')
axes[0,1].set_title('Class Loss'); axes[0,1].legend(); axes[0,1].grid(True)

axes[0,2].plot(epochs, df['train/dfl_loss'], label='Train', color='blue')
axes[0,2].plot(epochs, df['val/dfl_loss'],   label='Val',   color='orange')
axes[0,2].set_title('DFL Loss');  axes[0,2].legend(); axes[0,2].grid(True)

axes[1,0].plot(epochs, df['metrics/mAP50(B)'], color='green', linewidth=2)
axes[1,0].axhline(0.90, color='red', linestyle='--', label='90% target')
axes[1,0].set_title('mAP @ 0.5'); axes[1,0].legend(); axes[1,0].grid(True)

axes[1,1].plot(epochs, df['metrics/mAP50-95(B)'], color='purple', linewidth=2)
axes[1,1].set_title('mAP @ 0.5:0.95'); axes[1,1].grid(True)

axes[1,2].plot(epochs, df['metrics/precision(B)'], label='Precision', color='blue')
axes[1,2].plot(epochs, df['metrics/recall(B)'],    label='Recall',    color='red')
axes[1,2].axhline(0.90, color='gray', linestyle='--', label='90% target')
axes[1,2].set_title('Precision & Recall'); axes[1,2].legend(); axes[1,2].grid(True)

plt.tight_layout()
plt.savefig('exp10_yolo11s_curves.png', dpi=150)
plt.show()

# %%
best_model = YOLO('/content/runs/detect/ENDOX_runs/exp10_yolo11s/weights/best.pt')

metrics = best_model.val(
    data    = yaml_path,
    split   = 'test',
    imgsz   = IMG_SIZE,
    conf    = CONF_THRESH,
    iou     = IOU_THRESH,
    verbose = True
)

print(f'mAP@0.5   : {metrics.box.map50:.4f}  ({metrics.box.map50*100:.2f}%)')
print(f'mAP@0.5:95: {metrics.box.map:.4f}')
print(f'Precision : {metrics.box.mp:.4f}')
print(f'Recall    : {metrics.box.mr:.4f}')

exp_results = {
    'experiment': 'Exp 10',
    'model'     : 'YOLOv11s',
    'mAP50'     : round(metrics.box.map50, 4),
    'mAP50_95'  : round(metrics.box.map,   4),
    'precision' : round(metrics.box.mp,    4),
    'recall'    : round(metrics.box.mr,    4)
}
with open('exp10_results.json', 'w') as f:
  json.dump(exp_results, f)

print('exp10_results.json saved')
# Out:
# Ultralytics 8.4.129 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,413,187 parameters, 0 gradients, 21.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1874.5±357.9 MB/s, size: 61.4 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 41.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.4s
#                    all        150        150        0.9      0.905      0.897      0.632
# Speed: 3.3ms preprocess, 8.1ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /content/runs/detect/val-2
# mAP@0.5   : 0.8971  (89.71%)
# mAP@0.5:95: 0.6318
# Precision : 0.9005
# Recall    : 0.9050
# exp10_results.json saved

# %%
test_img_dir = f'{BASE}/images/test'
test_images  = random.sample(os.listdir(test_img_dir), 6)

fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('YOLOv11s — Test Predictions', fontsize=14, fontweight='bold')
axes = axes.flatten()

for i, fname in enumerate(test_images):
  result = best_model.predict(
      source  = os.path.join(test_img_dir, fname),
      conf    = CONF_THRESH,
      iou     = IOU_THRESH,
      verbose = False
  )[0]

  plotted = cv2.cvtColor(result.plot(), cv2.COLOR_BGR2RGB)
  boxes   = result.boxes
  title   = f'conf: {boxes.conf[0].item():.2f}' if len(boxes) > 0 else 'No detection'

  axes[i].imshow(plotted)
  axes[i].set_title(title)
  axes[i].axis('off')

plt.tight_layout()
plt.savefig('exp10_yolo11s_predictions.png', dpi=150)
plt.show()

# %%
thresholds = [0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.50]
recalls    = []
precisions = []
maps       = []

for thresh in thresholds:
  m = best_model.val(
      data=yaml_path, split='test',
      imgsz=IMG_SIZE, conf=thresh, iou=IOU_THRESH, verbose=False
  )
  recalls.append(m.box.mr)
  precisions.append(m.box.mp)
  maps.append(m.box.map50)
  print(f'conf={thresh:.2f} | mAP50={m.box.map50:.4f} | Precision={m.box.mp:.4f} | Recall={m.box.mr:.4f}')

best_idx    = maps.index(max(maps))
best_thresh = thresholds[best_idx]
print(f'Best threshold: {best_thresh} (mAP={maps[best_idx]:.4f})')

fig, ax = plt.subplots(figsize=(10, 5))
fig.suptitle('YOLOv11s — Threshold Sweep', fontsize=13, fontweight='bold')
ax.plot(thresholds, maps,       label='mAP@0.5',  color='green', linewidth=2, marker='o')
ax.plot(thresholds, precisions, label='Precision', color='blue',  linewidth=2, marker='s')
ax.plot(thresholds, recalls,    label='Recall',    color='red',   linewidth=2, marker='^')
ax.axvline(best_thresh, color='gray', linestyle='--', label=f'Best: {best_thresh}')
ax.axhline(0.90, color='black', linestyle=':', alpha=0.5)
ax.set_xlabel('Confidence Threshold')
ax.set_ylabel('Score')
ax.legend()
ax.grid(True, alpha=0.4)
plt.tight_layout()
plt.savefig('exp10_yolo11s_sweep.png', dpi=150)
plt.show()
# Out:
# Ultralytics 8.4.129 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2184.1±647.4 MB/s, size: 60.6 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 48.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        150        150        0.9      0.905      0.905      0.633
# Speed: 3.7ms preprocess, 8.2ms inference, 0.1ms loss, 2.1ms postprocess per image
# Results saved to /content/runs/detect/val-3
# conf=0.10 | mAP50=0.9050 | Precision=0.9005 | Recall=0.9050
# Ultralytics 8.4.129 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2268.3±782.1 MB/s, size: 57.2 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 52.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        150        150        0.9      0.905      0.897      0.632
# Speed: 2.8ms preprocess, 8.3ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /content/runs/detect/val-4
# conf=0.15 | mAP50=0.8971 | Precision=0.9005 | Recall=0.9050
# Ultralytics 8.4.129 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2159.0±655.1 MB/s, size: 72.3 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 44.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.5s
#                    all        150        150        0.9      0.905      0.897      0.627
# Speed: 5.2ms preprocess, 8.5ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /content/runs/detect/val-5
# conf=0.20 | mAP50=0.8971 | Precision=0.9005 | Recall=0.9050
# Ultralytics 8.4.129 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2064.1±752.9 MB/s, size: 67.8 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 41.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.8it/s 3.6s
#                    all        150        150        0.9      0.905      0.897      0.627
# Speed: 3.4ms preprocess, 8.7ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /content/runs/detect/val-6
# conf=0.25 | mAP50=0.8971 | Precision=0.9005 | Recall=0.9050
# Ultralytics 8.4.129 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1588.9±301.0 MB/s, size: 48.9 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 48.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.9it/s 3.4s
#                    all        150        150      0.901      0.907      0.888      0.623
# Speed: 3.2ms preprocess, 8.4ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to /content/runs/detect/val-7
# conf=0.30 | mAP50=0.8882 | Precision=0.9007 | Recall=0.9067
# Ultralytics 8.4.129 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2076.7±889.0 MB/s, size: 64.2 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 39.3Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.7s
#                    all        150        150      0.911      0.887       0.87      0.614
# Speed: 3.2ms preprocess, 8.6ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to /content/runs/detect/val-8
# conf=0.35 | mAP50=0.8701 | Precision=0.9110 | Recall=0.8867
# Ultralytics 8.4.129 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1672.7±408.8 MB/s, size: 56.2 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 48.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.0it/s 3.4s
#                    all        150        150      0.917       0.88      0.861      0.612
# Speed: 3.3ms preprocess, 8.2ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /content/runs/detect/val-9
# conf=0.40 | mAP50=0.8610 | Precision=0.9167 | Recall=0.8800
# Ultralytics 8.4.129 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1797.1±696.5 MB/s, size: 59.3 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 41.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.7it/s 3.6s
#                    all        150        150      0.928      0.853      0.842      0.601
# Speed: 3.2ms preprocess, 8.5ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to /content/runs/detect/val-10
# conf=0.50 | mAP50=0.8425 | Precision=0.9275 | Recall=0.8533
# Best threshold: 0.1 (mAP=0.9050)

# %%
import shutil
from google.colab import files

shutil.copy('/content/runs/detect/ENDOX_runs/exp10_yolo11s/weights/best.pt', 'endox_exp10_yolo11s.pt')
print('Saved: endox_exp10_yolo11s.pt')

files.download('endox_exp10_yolo11s.pt')
files.download('exp10_results.json')
files.download('exp10_yolo11s_sweep.png')
# Out:
# Saved: endox_exp10_yolo11s.pt
