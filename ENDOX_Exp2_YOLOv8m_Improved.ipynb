# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulrahman-Mahmoud-12/ENDO-X/blob/osama/ENDOX_Exp2_YOLOv8m_Improved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ENDO-X — Polyp Detection: YOLOv8m Improved
# ## Kvasir-SEG | Target: mAP@0.5 > 90% | Recall > 90%
# ---
# | Metric | Previous | Target |
# |---|---|---|
# | mAP@0.5 | 75.16% | > 90% |
# | Recall | 78.67% | > 90% |
# | Precision | 84.07% | > 85% |

# %%
# !pip install -U ultralytics -q

import os, zipfile

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d debeshjha1/kvasirseg

with zipfile.ZipFile('kvasirseg.zip', 'r') as zip_ref:
  zip_ref.extractall('kvasir')

print(os.listdir('kvasir/Kvasir-SEG/Kvasir-SEG'))
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 2.2 MB/s eta 0:00:00
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2)
# Dataset URL: https://www.kaggle.com/datasets/debeshjha1/kvasirseg
# License(s): copyright-authors
# Downloading kvasirseg.zip to /content
# 100% 144M/144M [00:00<00:00, 177MB/s]
#
# ['annotated_images', 'masks', 'images', 'bbox', '1911.07069.pdf']

# %%
import os, cv2, csv, shutil, random, yaml, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from ultralytics import YOLO
import torch

print('GPU:', torch.cuda.is_available())
if torch.cuda.is_available():
  print(torch.cuda.get_device_name(0))
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart#ultralytics-settings.
# GPU: True
# Tesla T4

# %%
IMAGE_DIR = 'kvasir/Kvasir-SEG/Kvasir-SEG/images'
CSV_DIR   = 'kvasir/Kvasir-SEG/Kvasir-SEG/bbox'

all_keys = [f.replace('.jpg', '') for f in os.listdir(IMAGE_DIR) if f.endswith('.jpg')]

print('Total images:', len(all_keys))

with open(os.path.join(CSV_DIR, all_keys[0] + '.csv'), 'r') as f:
  print(f.read())
# Out:
# Total images: 1000
# class_name,xmin,ymin,xmax,ymax
# polyp,372,226,607,389

# %%
sample_keys = random.sample(all_keys, 6)

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
fig.suptitle('Kvasir-SEG Polyp Detection', fontsize=14, fontweight='bold')
axes = axes.flatten()

for i, key in enumerate(sample_keys):
  img = cv2.imread(os.path.join(IMAGE_DIR, key + '.jpg'))
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

  with open(os.path.join(CSV_DIR, key + '.csv'), 'r') as f:
    row = next(csv.DictReader(f))

  bx = float(row['xmin'])
  by = float(row['ymin'])
  bw = float(row['xmax']) - bx
  bh = float(row['ymax']) - by

  axes[i].imshow(img)
  axes[i].add_patch(patches.Rectangle((bx, by), bw, bh, linewidth=3, edgecolor='lime', facecolor='none'))
  axes[i].set_title(f'{img.shape[1]}x{img.shape[0]}')
  axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
def read_bbox_csv(csv_path, img_w, img_h):
  with open(csv_path, 'r') as f:
    row = next(csv.DictReader(f))
  x1 = float(row['xmin']);  y1 = float(row['ymin'])
  x2 = float(row['xmax']);  y2 = float(row['ymax'])
  bw = x2 - x1;             bh = y2 - y1
  cx = max(0., min(1., (x1 + bw / 2) / img_w))
  cy = max(0., min(1., (y1 + bh / 2) / img_h))
  nw = max(0., min(1., bw / img_w))
  nh = max(0., min(1., bh / img_h))
  return f'0 {cx:.6f} {cy:.6f} {nw:.6f} {nh:.6f}'


BASE = 'dataset'
for split in ['train', 'val', 'test']:
  os.makedirs(f'{BASE}/images/{split}', exist_ok=True)
  os.makedirs(f'{BASE}/labels/{split}', exist_ok=True)

train_keys, temp_keys = train_test_split(all_keys, test_size=0.30, random_state=42)
val_keys,   test_keys = train_test_split(temp_keys, test_size=0.50, random_state=42)

print(f'Train:{len(train_keys)} | Val:{len(val_keys)} | Test:{len(test_keys)}')

def build_split(keys, split_name):
  for key in keys:
    img_path = os.path.join(IMAGE_DIR, key + '.jpg')
    csv_path = os.path.join(CSV_DIR,   key + '.csv')
    img      = cv2.imread(img_path)
    h, w     = img.shape[:2]
    shutil.copy(img_path, f'{BASE}/images/{split_name}/{key}.jpg')
    with open(f'{BASE}/labels/{split_name}/{key}.txt', 'w') as f:
      f.write(read_bbox_csv(csv_path, w, h) + '\n')

build_split(train_keys, 'train')
build_split(val_keys,   'val')
build_split(test_keys,  'test')

print('Done')
print('images/train:', len(os.listdir(f'{BASE}/images/train')))
print('labels/train:', len(os.listdir(f'{BASE}/labels/train')))
# Out:
# Train:700 | Val:150 | Test:150
# Done
# images/train: 700
# labels/train: 700

# %%
dataset_yaml = {
    'path' : '/content/dataset',
    'train': 'images/train',
    'val'  : 'images/val',
    'test' : 'images/test',
    'nc'   : 1,
    'names': ['polyp']
}

yaml_path = 'kvasir_detection.yaml'
with open(yaml_path, 'w') as f:
  yaml.dump(dataset_yaml, f, default_flow_style=False)

with open(yaml_path, 'r') as f:
  print(f.read())
# Out:
# names:
# - polyp
# nc: 1
# path: /content/dataset
# test: images/test
# train: images/train
# val: images/val

# %%
MODEL_SIZE    = 'yolov8m.pt'
IMG_SIZE      = 640
EPOCHS        = 100
BATCH_SIZE    = 8
LR0           = 0.005
LRF           = 0.0005
WARMUP_EPOCHS = 5
PATIENCE      = 30
CLOSE_MOSAIC  = 15
CONF_THRESH   = 0.15
IOU_THRESH    = 0.35

print(f'Model       : {MODEL_SIZE}')
print(f'Epochs      : {EPOCHS}')
print(f'Batch       : {BATCH_SIZE}')
print(f'LR          : {LR0} → {LRF}')
print(f'Conf thresh : {CONF_THRESH}')
print(f'IoU thresh  : {IOU_THRESH}')
# Out:
# Model       : yolov8m.pt
# Epochs      : 100
# Batch       : 8
# LR          : 0.005 → 0.0005
# Conf thresh : 0.15
# IoU thresh  : 0.35

# %%
model = YOLO(MODEL_SIZE)
print(f'Params: {sum(p.numel() for p in model.model.parameters()):,}')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8m.pt to 'yolov8m.pt': 100% ━━━━━━━━━━━━ 49.7MB 83.1MB/s 0.6s
# Params: 25,902,640

# %%
results = model.train(
    data          = yaml_path,
    epochs        = EPOCHS,
    imgsz         = IMG_SIZE,
    batch         = BATCH_SIZE,
    lr0           = LR0,
    lrf           = LRF,
    warmup_epochs = WARMUP_EPOCHS,
    patience      = PATIENCE,
    close_mosaic  = CLOSE_MOSAIC,
    optimizer     = 'Adam',
    cos_lr        = True,
    augment       = True,
    mosaic        = 1.0,
    mixup         = 0.15,
    degrees       = 15.0,
    scale         = 0.6,
    shear         = 2.0,
    fliplr        = 0.5,
    flipud        = 0.3,
    hsv_h         = 0.02,
    hsv_s         = 0.8,
    hsv_v         = 0.5,
    save          = True,
    project       = 'ENDOX_runs',
    name          = 'exp2_yolov8m_improved',
    verbose       = True
)

print('Done')
# Out:
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=15, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=kvasir_detection.yaml, degrees=15.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.3, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.02, hsv_s=0.8, hsv_v=0.5, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.005, lrf=0.0005, mask_ratio=4, max_det=300, mixup=0.15, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp2_yolov8m_improved, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=ENDOX_runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/ENDOX_runs/exp2_yolov8m_improved, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.6, seed=0, shear=2.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=5, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 27.8MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776275  ultralytics.nn.modules.head.Detect           [1, 16, None, [192, 384, 576]]
# Model summary: 170 layers, 25,856,899 parameters, 25,856,883 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: downloading yolo26n.pt for AMP checks (one-time, not used for training)...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'weights/yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 88.5MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1335.4±469.7 MB/s, size: 46.7 KB)
# train: Scanning /content/dataset/labels/train... 700 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 700/700 1.9Kit/s 0.4s
# train: New cache created: /content/dataset/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 485.3±132.8 MB/s, size: 59.5 KB)
# val: Scanning /content/dataset/labels/val... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 2.0Kit/s 0.1s
# val: New cache created: /content/dataset/labels/val.cache
# optimizer: Adam(lr=0.005, momentum=0.937) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Plotting labels to /content/runs/detect/ENDOX_runs/exp2_yolov8m_improved/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/ENDOX_runs/exp2_yolov8m_improved
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100       3.3G      1.872      2.539      2.231          5        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 25.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.4it/s 3.0s
#                    all        150        150    0.00249       0.48    0.00156   0.000476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.38G      1.959      2.553      2.307         13        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 26.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.8it/s 2.1s
#                    all        150        150     0.0683        0.3     0.0421     0.0149
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.38G       1.86      2.415      2.206         10        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 26.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.3it/s 2.3s
#                    all        150        150      0.144       0.44       0.16     0.0472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.38G       1.83      2.323      2.154         11        640: 100% ━━━━━━━━━━━━ 88/88 3.3it/s 26.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.7it/s 2.1s
#                    all        150        150      0.391       0.22      0.218     0.0929
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      4.38G       1.79       2.33      2.149          8        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 25.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.8it/s 2.1s
#                    all        150        150      0.463        0.5       0.43      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.38G      1.748      2.239      2.143         11        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 25.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.7it/s 2.1s
#                    all        150        150      0.508      0.461      0.471      0.192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.38G      1.734      2.179      2.108          9        640: 100% ━━━━━━━━━━━━ 88/88 3.3it/s 26.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.1it/s 2.4s
#                    all        150        150      0.322      0.527       0.36      0.151
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.38G      1.697      2.198      2.063          8        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 25.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.8it/s 2.1s
#                    all        150        150      0.557      0.673      0.613      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.38G      1.675      2.086      2.028         11        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 25.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.7it/s 2.1s
#                    all        150        150      0.575      0.527      0.549      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.38G      1.637      2.096      2.024          8        640: 100% ━━━━━━━━━━━━ 88/88 3.3it/s 26.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.6it/s 2.2s
#                    all        150        150      0.501       0.55      0.521      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.38G       1.63      2.069      2.004         12        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 26.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.8it/s 2.1s
#                    all        150        150      0.598      0.593      0.595      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.38G      1.593      2.072       1.98          8        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 25.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      4.39G       1.15      1.207      1.553          4        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 26.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.7it/s 2.1s
#                    all        150        150      0.791      0.787      0.848      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      4.39G       1.15      1.195      1.568          9        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 26.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.6it/s 2.2s
#                    all        150        150      0.771      0.793      0.839      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      4.39G      1.117      1.169      1.536         11        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 25.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.6it/s 2.2s
#                    all        150        150      0.798        0.8      0.856      0.565
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      4.39G       0.97       1.05      1.462          4        640: 100% ━━━━━━━━━━━━ 88/88 3.2it/s 27.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.2it/s 2.4s
#                    all        150        150      0.823      0.807      0.864      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      4.39G     0.9951     0.9259      1.489          4        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 25.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.9it/s 2.0s
#                    all        150        150      0.776       0.82      0.857      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      4.39G     0.9433     0.8643      1.454          4        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 25.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.8it/s 2.1s
#                    all        150        150      0.814      0.767      0.863      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      4.39G     0.9688     0.8559      1.456          4        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 26.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.8it/s 2.1s
#                    all        150        150      0.803      0.767      0.866      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      4.39G     0.9461     0.8526      1.445          4        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 25.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.9it/s 2.1s
#                    all        150        150      0.821      0.773      0.881      0.617
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      4.39G     0.9179     0.8044       1.41          4        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 26.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.9it/s 2.6s
#                    all        150        150      0.817       0.84      0.885      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      4.39G     0.9087     0.7929      1.405          4        640: 100% ━━━━━━━━━━━━ 88/88 3.3it/s 26.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.8it/s 2.1s
#                    all        150        150      0.817      0.813      0.883      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      4.39G     0.9157     0.7751       1.43          4        640: 100% ━━━━━━━━━━━━ 88/88 3.5it/s 25.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.5it/s 2.2s
#                    all        150        150      0.789       0.82      0.878       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      4.39G     0.9445     0.8149      1.441          4        640: 100% ━━━━━━━━━━━━ 88/88 3.3it/s 26.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.7it/s 2.2s
#                    all        150        150      0.865       0.78      0.886      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      4.39G     0.9589     0.7849      1.453          4        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 25.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.7it/s 2.1s
#                    all        150        150       0.86       0.78      0.886      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      4.39G     0.9358     0.7946       1.44          4        640: 100% ━━━━━━━━━━━━ 88/88 3.5it/s 25.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.4it/s 2.3s
#                    all        150        150      0.873      0.777      0.886      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      4.39G     0.9324     0.7568      1.425          4        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 25.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.8it/s 2.1s
#                    all        150        150      0.834        0.8      0.888       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      4.39G     0.9055     0.7613      1.404          4        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 26.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 3.9it/s 2.5s
#                    all        150        150      0.854       0.78      0.888      0.619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      4.39G     0.9196     0.7754       1.41          4        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 26.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.9it/s 2.0s
#                    all        150        150      0.836      0.793      0.887      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      4.39G     0.9241     0.7886       1.42          4        640: 100% ━━━━━━━━━━━━ 88/88 3.4it/s 25.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 4.0it/s 2.5s
#                    all        150        150      0.853      0.773      0.887      0.624
#
# 100 epochs completed in 0.867 hours.
# Optimizer stripped from /content/runs/detect/ENDOX_runs/exp2_yolov8m_improved/weights/last.pt, 52.0MB
# Optimizer stripped from /content/runs/detect/ENDOX_runs/exp2_yolov8m_improved/weights/best.pt, 52.0MB
#
# Validating /content/runs/detect/ENDOX_runs/exp2_yolov8m_improved/weights/best.pt...
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 93 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 1.9it/s 5.4s
#                    all        150        150      0.845      0.837      0.899      0.655
# Speed: 0.2ms preprocess, 30.6ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /content/runs/detect/ENDOX_runs/exp2_yolov8m_improved
# Done

# %%
df = pd.read_csv('/content/runs/detect/ENDOX_runs/exp2_yolov8m_improved/results.csv')
df.columns = df.columns.str.strip()
epochs = df['epoch']

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle('YOLOv8m Improved — Training History', fontsize=14, fontweight='bold')

axes[0,0].plot(epochs, df['train/box_loss'], label='Train', color='blue')
axes[0,0].plot(epochs, df['val/box_loss'],   label='Val',   color='orange')
axes[0,0].set_title('Box Loss');  axes[0,0].legend(); axes[0,0].grid(True)

axes[0,1].plot(epochs, df['train/cls_loss'], label='Train', color='blue')
axes[0,1].plot(epochs, df['val/cls_loss'],   label='Val',   color='orange')
axes[0,1].set_title('Class Loss'); axes[0,1].legend(); axes[0,1].grid(True)

axes[0,2].plot(epochs, df['train/dfl_loss'], label='Train', color='blue')
axes[0,2].plot(epochs, df['val/dfl_loss'],   label='Val',   color='orange')
axes[0,2].set_title('DFL Loss');  axes[0,2].legend(); axes[0,2].grid(True)

axes[1,0].plot(epochs, df['metrics/mAP50(B)'], color='green', linewidth=2)
axes[1,0].axhline(0.90, color='red', linestyle='--', label='90% target')
axes[1,0].set_title('mAP @ 0.5'); axes[1,0].legend(); axes[1,0].grid(True)

axes[1,1].plot(epochs, df['metrics/mAP50-95(B)'], color='purple', linewidth=2)
axes[1,1].set_title('mAP @ 0.5:0.95'); axes[1,1].grid(True)

axes[1,2].plot(epochs, df['metrics/precision(B)'], label='Precision', color='blue')
axes[1,2].plot(epochs, df['metrics/recall(B)'],    label='Recall',    color='red')
axes[1,2].axhline(0.90, color='gray', linestyle='--', label='90% target')
axes[1,2].set_title('Precision & Recall'); axes[1,2].legend(); axes[1,2].grid(True)

plt.tight_layout()
plt.savefig('training_curves.png', dpi=150)
plt.show()

# %%
best_model = YOLO('/content/runs/detect/ENDOX_runs/exp2_yolov8m_improved/weights/best.pt')

metrics = best_model.val(
    data    = yaml_path,
    split   = 'test',
    imgsz   = IMG_SIZE,
    conf    = CONF_THRESH,
    iou     = IOU_THRESH,
    verbose = True
)

print('\nBefore → After')
print(f'mAP@0.5   : 0.7516 → {metrics.box.map50:.4f}  ({(metrics.box.map50-0.7516)*100:+.1f}%)')
print(f'Recall    : 0.7867 → {metrics.box.mr:.4f}  ({(metrics.box.mr-0.7867)*100:+.1f}%)')
print(f'Precision : 0.8407 → {metrics.box.mp:.4f}')
print(f'mAP@0.5:95: 0.4180 → {metrics.box.map:.4f}')

exp2_results = {
    'experiment': 'Exp 2',
    'model'     : 'YOLOv8m Improved',
    'mAP50'     : round(metrics.box.map50, 4),
    'mAP50_95'  : round(metrics.box.map,   4),
    'precision' : round(metrics.box.mp,    4),
    'recall'    : round(metrics.box.mr,    4)
}
with open('exp2_results.json', 'w') as f:
  json.dump(exp2_results, f)

print('\nexp2_results.json saved')
# Out:
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 93 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 5.9±2.6 MB/s, size: 53.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# val: Scanning /content/dataset/labels/test... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 349.5it/s 0.4s
# val: New cache created: /content/dataset/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.2it/s 4.6s
#                    all        150        150       0.86       0.88      0.864      0.573
# Speed: 3.1ms preprocess, 22.6ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /content/runs/detect/val
#
# Before → After
# mAP@0.5   : 0.7516 → 0.8637  (+11.2%)
# Recall    : 0.7867 → 0.8800  (+9.3%)
# Precision : 0.8407 → 0.8599
# mAP@0.5:95: 0.4180 → 0.5726
#
# exp2_results.json saved

# %%
test_img_dir = f'{BASE}/images/test'
test_images  = random.sample(os.listdir(test_img_dir), 6)

fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('YOLOv8m Improved — Test Predictions', fontsize=14, fontweight='bold')
axes = axes.flatten()

for i, fname in enumerate(test_images):
  result = best_model.predict(
      source  = os.path.join(test_img_dir, fname),
      conf    = CONF_THRESH,
      iou     = IOU_THRESH,
      verbose = False
  )[0]

  plotted = cv2.cvtColor(result.plot(), cv2.COLOR_BGR2RGB)
  boxes   = result.boxes
  title   = f'conf: {boxes.conf[0].item():.2f}' if len(boxes) > 0 else 'No detection'

  axes[i].imshow(plotted)
  axes[i].set_title(title)
  axes[i].axis('off')

plt.tight_layout()
plt.savefig('test_predictions.png', dpi=150)
plt.show()

# %%
thresholds = [0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.50]
recalls    = []
precisions = []
maps       = []

for thresh in thresholds:
  m = best_model.val(
      data=yaml_path, split='test',
      imgsz=IMG_SIZE, conf=thresh, iou=IOU_THRESH, verbose=False
  )
  recalls.append(m.box.mr)
  precisions.append(m.box.mp)
  maps.append(m.box.map50)
  print(f'conf={thresh:.2f} | mAP50={m.box.map50:.4f} | Precision={m.box.mp:.4f} | Recall={m.box.mr:.4f}')

best_idx    = maps.index(max(maps))
best_thresh = thresholds[best_idx]
print(f'\nBest threshold: {best_thresh} (mAP={maps[best_idx]:.4f})')

fig, ax = plt.subplots(figsize=(10, 5))
fig.suptitle('Confidence Threshold Sweep', fontsize=13, fontweight='bold')
ax.plot(thresholds, maps,       label='mAP@0.5',  color='green', linewidth=2, marker='o')
ax.plot(thresholds, precisions, label='Precision', color='blue',  linewidth=2, marker='s')
ax.plot(thresholds, recalls,    label='Recall',    color='red',   linewidth=2, marker='^')
ax.axvline(best_thresh, color='gray', linestyle='--', label=f'Best: {best_thresh}')
ax.axhline(0.90, color='black', linestyle=':', alpha=0.5)
ax.set_xlabel('Confidence Threshold')
ax.set_ylabel('Score')
ax.legend()
ax.grid(True, alpha=0.4)
plt.tight_layout()
plt.savefig('threshold_sweep.png', dpi=150)
plt.show()
# Out:
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1282.3±788.1 MB/s, size: 62.4 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 52.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 1.7it/s 5.8s
#                    all        150        150       0.86       0.88      0.879      0.578
# Speed: 5.0ms preprocess, 23.1ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to /content/runs/detect/val-2
# conf=0.10 | mAP50=0.8791 | Precision=0.8599 | Recall=0.8800
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2097.5±612.1 MB/s, size: 60.6 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 57.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.0it/s 4.9s
#                    all        150        150       0.86       0.88      0.864      0.573
# Speed: 3.0ms preprocess, 24.1ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to /content/runs/detect/val-3
# conf=0.15 | mAP50=0.8637 | Precision=0.8599 | Recall=0.8800
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1806.4±521.4 MB/s, size: 57.2 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 57.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.0it/s 5.0s
#                    all        150        150       0.86       0.88      0.864      0.568
# Speed: 3.4ms preprocess, 24.2ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /content/runs/detect/val-4
# conf=0.20 | mAP50=0.8637 | Precision=0.8599 | Recall=0.8800
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1836.3±404.2 MB/s, size: 72.3 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 41.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 1.9it/s 5.2s
#                    all        150        150       0.86       0.88      0.855      0.567
# Speed: 3.2ms preprocess, 24.5ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /content/runs/detect/val-5
# conf=0.25 | mAP50=0.8554 | Precision=0.8599 | Recall=0.8800
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2333.5±567.2 MB/s, size: 67.8 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 62.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 1.9it/s 5.1s
#                    all        150        150       0.86       0.88      0.847      0.562
# Speed: 2.8ms preprocess, 24.7ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to /content/runs/detect/val-6
# conf=0.30 | mAP50=0.8469 | Precision=0.8599 | Recall=0.8800
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1278.0±85.6 MB/s, size: 48.9 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 48.4Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 1.7it/s 5.8s
#                    all        150        150      0.863       0.88      0.847      0.562
# Speed: 6.5ms preprocess, 24.4ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to /content/runs/detect/val-7
# conf=0.35 | mAP50=0.8469 | Precision=0.8627 | Recall=0.8800
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2047.1±773.7 MB/s, size: 64.2 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 57.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.0it/s 4.9s
#                    all        150        150      0.876      0.847       0.82      0.546
# Speed: 2.5ms preprocess, 23.9ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to /content/runs/detect/val-8
# conf=0.40 | mAP50=0.8205 | Precision=0.8759 | Recall=0.8467
# Ultralytics 8.4.128 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2248.3±671.6 MB/s, size: 56.2 KB)
# val: Scanning /content/dataset/labels/test.cache... 150 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 150/150 57.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 2.1it/s 4.8s
#                    all        150        150      0.897      0.813      0.794      0.533
# Speed: 2.9ms preprocess, 23.6ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /content/runs/detect/val-9
# conf=0.50 | mAP50=0.7941 | Precision=0.8971 | Recall=0.8133
#
# Best threshold: 0.1 (mAP=0.8791)

# %%
shutil.copy(
    '/content/runs/detect/ENDOX_runs/exp2_yolov8m_improved/weights/best.pt',
    'endox_yolov8m_improved.pt'
)
print('Saved: endox_yolov8m_improved.pt')

from google.colab import files
files.download('endox_yolov8m_improved.pt')
files.download('exp2_results.json')
files.download('threshold_sweep.png')
# Out:
# Saved: endox_yolov8m_improved.pt
